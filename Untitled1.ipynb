# %% [markdown]
# <a href="https://colab.research.google.com/github/gnarendra9014-blind/Cognifyz-ML-Internship/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
exec(open('Task3_Cuisine_Classification.py').read())
# Out:
# ==================================================
# TASK 3: CUISINE CLASSIFICATION
# ==================================================
#
# Dataset Shape: (600, 8)
#
# Cuisine Distribution:
# Cuisine
# Indian      110
# Italian     104
# Japanese    101
# American     90
# Chinese      90
# Mexican      80
# Name: count, dtype: int64
#
# Missing Values:
# City                     0
# Price_Range              0
# Votes                   14
# Average_Cost_for_Two     0
# Aggregate_Rating         0
# Has_Online_Delivery      0
# Has_Table_Booking        0
# Cuisine                 25
# dtype: int64
#
# --- PREPROCESSING ---
# Missing values after handling: 0
# Cuisine classes: ['American', 'Chinese', 'Indian', 'Italian', 'Japanese', 'Mexican']
#
# Training set size: 480
# Testing set size:  120
#
# --- MODEL EVALUATION ---
# Model                     Accuracy
# ----------------------------------------
# Logistic Regression       0.1667
# Random Forest             0.2083
#
# --- DETAILED CLASSIFICATION REPORT (Random Forest) ---
#               precision    recall  f1-score   support
#
#     American       0.14      0.11      0.12        18
#      Chinese       0.07      0.06      0.06        18
#       Indian       0.42      0.52      0.47        27
#      Italian       0.19      0.24      0.21        21
#     Japanese       0.10      0.10      0.10        20
#      Mexican       0.08      0.06      0.07        16
#
#     accuracy                           0.21       120
#    macro avg       0.17      0.18      0.17       120
# weighted avg       0.19      0.21      0.20       120
# ✅ Task 3 Complete! Plot saved as 'task3_results.png'
