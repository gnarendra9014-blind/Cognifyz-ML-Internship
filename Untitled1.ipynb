# %% [markdown]
# <a href="https://colab.research.google.com/github/gnarendra9014-blind/Cognifyz-ML-Internship/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
exec(open('Task1_Predict_Restaurant_Ratings.py').read())
# Out:
# ...
# TASK 1: PREDICT RESTAURANT RATINGS
# ...
#
# Dataset Shape: (500, 9)
#
# First 5 rows:
#   Restaurant_Name       City   Cuisine  Price_Range   Votes  \
# 0    Restaurant_0    Chennai  Japanese            2  1311.0
# 1    Restaurant_1    Kolkata   Mexican            2  2551.0
# 2    Restaurant_2  Bangalore    Indian            1  2061.0
# 3    Restaurant_3    Kolkata  Japanese            2   451.0
# 4    Restaurant_4    Kolkata  American            4  2086.0
#
#    Average_Cost_for_Two  Has_Online_Delivery  Has_Table_Booking  \
# 0                  2556                    1                  0
# 1                   894                    1                  0
# 2                  2535                    1                  0
# 3                   506                    0                  0
# 4                  2189                    1                  1
#
#    Aggregate_Rating
# 0               1.6
# 1               4.1
# 2               4.7
# 3               2.5
# 4               4.5
#
# ...
